# %% [markdown]
# <a href="https://colab.research.google.com/github/thanmai09/new-beginnings/blob/main/rev.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s = "thannu"
print(s[5]+s[4]+s[3]+s[2]+s[1]+s[0])
# Out:
# unnaht

# %%
s = "ABCD"
ans = ""
ans = s[3]
ans += s[2]
ans += s[1]
ans += s[0]
print(ans)
# Out:
# DCBA

# %%
s = "ABCD"
ans = ""
for i in range(3,-1,-1):
  ans += s[i]
print(ans)
# Out:
# DCBA
